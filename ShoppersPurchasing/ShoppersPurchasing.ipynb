# %%
import pandas
import numpy
from pandas_profiling import ProfileReport
from statistics import mode as stmode
import matplotlib.pyplot as mtpl
from sklearn.model_selection import train_test_split

# %%
dataset = pandas.read_csv('RCDataset-ML-1.csv')

# %%
dataset.keys(), dataset.shape
# Out:
# (Index(['Administrative', 'Administrative_Duration', 'Informational',
#         'Informational_Duration', 'ProductRelated', 'ProductRelated_Duration',
#         'BounceRates', 'ExitRates', 'PageValues', 'SpecialDay', 'Month',
#         'OperatingSystems', 'Browser', 'Region', 'TrafficType', 'VisitorType',
#         'Weekend', 'Revenue'],
#        dtype='object'), (12330, 18))

# %%
dataset.describe()
# Out:
#        Administrative  Administrative_Duration  Informational  \
# count    12215.000000             12225.000000   12196.000000
# mean         2.315759                80.741179       0.502706
# std          3.319969               176.660783       1.271342
# min          0.000000                 0.000000       0.000000
# 25%          0.000000                 0.000000       0.000000
# 50%          1.000000                 7.000000       0.000000
# 75%          4.000000                92.750000       0.000000
# max         27.000000              3398.750000      24.000000
#
#        Informational_Duration  ProductRelated  ProductRelated_Duration  \
# count            12204.000000    12196.000000             12191.000000
# mean                34.733067       31.814447              1192.220406
# std                141.364602       44.607472              1905.738105
# min                  0.000000        0.000000                 0.000000
# ...

# %%
dataset.isna().sum()
# Out:
# Administrative             115
# Administrative_Duration    105
# Informational              134
# Informational_Duration     126
# ProductRelated             134
# ProductRelated_Duration    139
# BounceRates                114
# ExitRates                  122
# PageValues                 108
# SpecialDay                 129
# Month                      118
# OperatingSystems           116
# Browser                    112
# Region                     126
# TrafficType                151
# VisitorType                116
# Weekend                    131
# Revenue                      0
# dtype: int64

# %%
dataset.Administrative.fillna(dataset.Administrative.mean(), inplace=True)
dataset.Administrative_Duration.fillna(dataset.Administrative_Duration.mean(), inplace=True)
dataset.Informational.fillna(dataset.Informational.mean(), inplace=True)
dataset.Informational_Duration.fillna(dataset.Informational_Duration.mean(), inplace=True)
dataset.ProductRelated.fillna(dataset.ProductRelated.mean(), inplace=True)
dataset.ProductRelated_Duration.fillna(dataset.ProductRelated_Duration.mean(), inplace=True)
dataset.BounceRates.fillna(dataset.BounceRates.mean(), inplace=True)
dataset.ExitRates.fillna(dataset.ExitRates.mean(), inplace=True)
dataset.PageValues.fillna(dataset.PageValues.mean(), inplace=True)
dataset.SpecialDay.fillna(dataset.SpecialDay.mean(), inplace=True)

# %%
dataset.Month.fillna(stmode(dataset.Month), inplace=True)
dataset.OperatingSystems.fillna(stmode(dataset.OperatingSystems), inplace=True)
dataset.Browser.fillna(stmode(dataset.Browser), inplace=True)
dataset.Region.fillna(stmode(dataset.Region), inplace=True)
dataset.TrafficType.fillna(stmode(dataset.TrafficType), inplace=True)
dataset.VisitorType.fillna(stmode(dataset.VisitorType), inplace=True)
dataset.Weekend.fillna(stmode(dataset.Weekend), inplace=True)

# %%
dataset = pandas.get_dummies(dataset, columns=['Month', 'OperatingSystems', 'Browser', 'Region', 'TrafficType', 'VisitorType', 'Weekend'])

# %%
dataset['Revenue'] = movies.title.apply(lambda n == "True": n = 1)
# Out:
#   File "<ipython-input-68-0d5048de88c2>", line 1
#     dataset.Revenue.apply(lambda n == "True": n = 1)
#                                     ^
# SyntaxError: invalid syntax

# %%
dataset.keys()
# Out:
# Index(['Administrative', 'Administrative_Duration', 'Informational',
#        'Informational_Duration', 'ProductRelated', 'ProductRelated_Duration',
#        'BounceRates', 'ExitRates', 'PageValues', 'SpecialDay', 'Month_Aug',
#        'Month_Dec', 'Month_Feb', 'Month_Jul', 'Month_June', 'Month_Mar',
#        'Month_May', 'Month_Nov', 'Month_Oct', 'Month_Sep',
#        'OperatingSystems_1.0', 'OperatingSystems_2.0', 'OperatingSystems_3.0',
#        'OperatingSystems_4.0', 'OperatingSystems_5.0', 'OperatingSystems_6.0',
#        'OperatingSystems_7.0', 'OperatingSystems_8.0', 'Browser_1.0',
#        'Browser_2.0', 'Browser_3.0', 'Browser_4.0', 'Browser_5.0',
#        'Browser_6.0', 'Browser_7.0', 'Browser_8.0', 'Browser_9.0',
#        'Browser_10.0', 'Browser_11.0', 'Browser_12.0', 'Browser_13.0',
#        'Region_1.0', 'Region_2.0', 'Region_3.0', 'Region_4.0', 'Region_5.0',
#        'Region_6.0', 'Region_7.0', 'Region_8.0', 'Region_9.0',
# ...

# %%
train, test = train_test_split(dataset)

# %%
dataset_features = ['TrafficType_1.0', 'TrafficType_2.0', 'TrafficType_3.0',
       'TrafficType_4.0', 'TrafficType_5.0', 'TrafficType_6.0',
       'TrafficType_7.0', 'TrafficType_8.0', 'TrafficType_9.0',
       'TrafficType_10.0', 'TrafficType_11.0', 'TrafficType_12.0',
       'TrafficType_13.0', 'TrafficType_14.0', 'TrafficType_15.0',
       'TrafficType_16.0', 'TrafficType_17.0', 'TrafficType_18.0',
       'TrafficType_19.0', 'TrafficType_20.0','SpecialDay','Revenue_False', 'Revenue_True' ]

# %%
train = train[dataset_features]
test = test[dataset_features]

# %%
train.keys()
# Out:
# Index(['TrafficType_1.0', 'TrafficType_2.0', 'TrafficType_3.0',
#        'TrafficType_4.0', 'TrafficType_5.0', 'TrafficType_6.0',
#        'TrafficType_7.0', 'TrafficType_8.0', 'TrafficType_9.0',
#        'TrafficType_10.0', 'TrafficType_11.0', 'TrafficType_12.0',
#        'TrafficType_13.0', 'TrafficType_14.0', 'TrafficType_15.0',
#        'TrafficType_16.0', 'TrafficType_17.0', 'TrafficType_18.0',
#        'TrafficType_19.0', 'TrafficType_20.0', 'SpecialDay', 'Revenue_False',
#        'Revenue_True'],
#       dtype='object')

# %%
xtrain = train.drop(['Revenue_False', 'Revenue_True'], axis=1)
xtest = test.drop(['Revenue_False', 'Revenue_True'], axis=1)
ytrain = train.Survived
yval = val.Survived
